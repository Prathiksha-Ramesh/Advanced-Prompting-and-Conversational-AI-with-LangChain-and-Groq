# %%
NEO4J_URI='neo4j+s://955cd91b.databases.neo4j.io:7687'
NEO4J_USERNAME='neo4j'
NEO4J_PASSWORD='WygIPlQMGaBqzxGa4lwgYoMueAt6gEbe0ZWTbY3NCd'

# %%
import os
os.environ['NEO4J_URI']=NEO4J_URI
os.environ['NEO4J_USERNAME']=NEO4J_USERNAME
os.environ['NEO4J_PASSWORD']=NEO4J_PASSWORD

# %%
from langchain_community.graphs import Neo4jGraph
graph=Neo4jGraph(url=NEO4J_URI,username=NEO4J_USERNAME,password=NEO4J_PASSWORD)
# Out:
# ---------------------------------------------------------------------------
# AuthError                                 Traceback (most recent call last)
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\langchain_community\graphs\neo4j_graph.py:370, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     369 try:
# --> 370     self._driver.verify_connectivity()
#     371 except neo4j.exceptions.ServiceUnavailable:
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\driver.py:974, in Driver.verify_connectivity(self, **config)
#     973 session_config = self._read_session_config(config)
# --> 974 self._get_server_info(session_config)
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\driver.py:1185, in Driver._get_server_info(self, session_config)
#    1184 with self._session(session_config) as session:
# -> 1185     return session._get_server_info()
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\work\session.py:173, in Session._get_server_info(self)
#     172 assert not self._connection
# --> 173 self._connect(READ_ACCESS, liveness_check_timeout=0)
#     174 server_info = self._connection.server_info
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\work\session.py:131, in Session._connect(self, access_mode, **acquire_kwargs)
#     130 try:
# --> 131     super()._connect(
#     132         access_mode, auth=self._config.auth, **acquire_kwargs
#     133     )
#     134 except asyncio.CancelledError:
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\work\workspace.py:161, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     160         log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 161         self._pool.update_routing_table(
#     162             database=self._config.database,
#     163             imp_user=self._config.impersonated_user,
#     164             bookmarks=self._get_bookmarks(),
#     165             auth=auth,
#     166             acquisition_timeout=acquisition_timeout,
#     167             database_callback=self._set_cached_database
#     168         )
#     169 acquire_kwargs_ = {
#     170     "access_mode": access_mode,
#     171     "timeout": acquisition_timeout,
#    (...)
#     175     "liveness_check_timeout": None,
#     176 }
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_pool.py:776, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     774 if prefer_initial_routing_address:
#     775     # TODO: Test this state
# --> 776     if self._update_routing_table_from(
#     777         self.address, database=database,
#     778         imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     779         acquisition_timeout=acquisition_timeout,
#     780         database_callback=database_callback
#     781     ):
#     782         # Why is only the first initial routing address used?
#     783         return
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_pool.py:722, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     719 for address in NetworkUtil.resolve_address(
#     720     router, resolver=self.pool_config.resolver
#     721 ):
# --> 722     new_routing_table = self.fetch_routing_table(
#     723         address=address, acquisition_timeout=acquisition_timeout,
#     724         database=database, imp_user=imp_user, bookmarks=bookmarks,
#     725         auth=auth
#     726     )
#     727     if new_routing_table is not None:
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_pool.py:659, in Neo4jPool.fetch_routing_table(self, address, acquisition_timeout, database, imp_user, bookmarks, auth)
#     658 try:
# --> 659     new_routing_info = self.fetch_routing_info(
#     660         address, database, imp_user, bookmarks, auth,
#     661         acquisition_timeout
#     662     )
#     663 except Neo4jError as e:
#     664     # checks if the code is an error that is caused by the client. In
#     665     # this case there is no sense in trying to fetch a RT from another
#     666     # router. Hence, the driver should fail fast during discovery.
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_pool.py:627, in Neo4jPool.fetch_routing_info(self, address, database, imp_user, bookmarks, auth, acquisition_timeout)
#     626     auth.force_auth = False
# --> 627 cx = self._acquire(address, auth, deadline, None)
#     628 try:
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_pool.py:315, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout)
#     314 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 315 return connection_creator()
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_pool.py:167, in IOPool._acquire_new_later.<locals>.connection_creator()
#     166 try:
# --> 167     connection = self.opener(
#     168         address, auth or self.pool_config.auth, deadline
#     169     )
#     170 except ServiceUnavailable:
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_pool.py:559, in Neo4jPool.open.<locals>.opener(addr, auth_manager, deadline)
#     558 def opener(addr, auth_manager, deadline):
# --> 559     return Bolt.open(
#     560         addr, auth_manager=auth_manager, deadline=deadline,
#     561         routing_context=routing_context, pool_config=pool_config
#     562     )
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:489, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     488 try:
# --> 489     connection.hello()
#     490 finally:
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_bolt5.py:581, in Bolt5x2.hello(self, dehydration_hooks, hydration_hooks)
#     580 self.send_all()
# --> 581 self.fetch_all()
#     582 check_supported_server_product(self.server_info.agent)
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:865, in Bolt.fetch_all(self)
#     864 while not response.complete:
# --> 865     detail_delta, summary_delta = self.fetch_message()
#     866     detail_count += detail_delta
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_bolt.py:851, in Bolt.fetch_message(self)
#     848 tag, fields = self.inbox.pop(
#     849     hydration_hooks=self.responses[0].hydration_hooks
#     850 )
# --> 851 res = self._process_message(tag, fields)
#     852 self.idle_since = perf_counter()
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_bolt5.py:376, in Bolt5x0._process_message(self, tag, fields)
#     375 try:
# --> 376     response.on_failure(summary_metadata or {})
#     377 except (ServiceUnavailable, DatabaseUnavailable):
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\neo4j\_sync\io\_common.py:283, in LogonResponse.on_failure(self, metadata)
#     282 Util.callback(handler)
# --> 283 raise Neo4jError.hydrate(**metadata)
#
# AuthError: {code: Neo.ClientError.Security.Unauthorized} {message: The client is unauthorized due to authentication failure.}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 from langchain_community.graphs import Neo4jGraph
# ----> 2 graph=Neo4jGraph(url=NEO4J_URI,username=NEO4J_USERNAME,password=NEO4J_PASSWORD)
#
# File c:\Users\prath\Downloads\bootcamp\Project-68\venv\Lib\site-packages\langchain_community\graphs\neo4j_graph.py:377, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     372     raise ValueError(
#     373         "Could not connect to Neo4j database. "
#     374         "Please ensure that the url is correct"
#     375     )
#     376 except neo4j.exceptions.AuthError:
# --> 377     raise ValueError(
#     378         "Could not connect to Neo4j database. "
#     379         "Please ensure that the username and password are correct"
#     380     )
#     381 # Set schema
#     382 if refresh_schema:
#
# ValueError: Could not connect to Neo4j database. Please ensure that the username and password are correct

# %%
moview_query="""
LOAD CSV WITH HEADERS FROM
'https:raw.githubusercontent.com/tomasonjo/blog-datasets/main/movies/movies_small.csv' as row
MERGE(m:Movie{id:row.movieId})
SET m.released=date(row.released),
    m.title=row.title,
    m.imdbRating=toFloat(row.imdbRating)
FOREACH (director in split(row.director,'|'))|
    MERGE (p:Person{name:trim(director)})
    MERGE(p)-[DIRECTED]->(m))
    MERGE(p)-[ACTED_IN]->(m))
FOREACH(genre in split(row.genes,'|'))|
    MERGE(g:Genre {name:trim(genre)})
    MERGE(m)-[:IN_GENRE]->(g))
"""
